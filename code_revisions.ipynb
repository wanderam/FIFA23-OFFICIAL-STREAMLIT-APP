# %%
import pandas as pd
from datetime import datetime

# %%
df_data = pd.read_csv('archive/CLEAN_FIFA23_official_data.csv', index_col=0)
df_data = df_data[df_data['Contract Valid Until'] >= 2023]  # datetime.today().year
df_data = df_data[df_data['Value(£)'] > 0]
df_data.sort_values(by='Overall', ascending=False, inplace=True)


df_data
# Out:
#            ID             Name  Age  \
# 41     188545   R. Lewandowski   33
# 56     158023         L. Messi   35
# 75     231747        K. Mbappé   23
# 124    165153       K. Benzema   34
# 3      192985     K. De Bruyne   31
# ...       ...              ...  ...
# 15568  269011        Zhao Ziye   18
# 15505  258802         B. Singh   22
# 15513  266751  22 Jung Ho Yeon   20
# 14353  269032    22 Chen Zeshi   16
# 16215  268279   22 J. Looschen   24
#
#                                                   Photo     Nationality  \
# 41     https://cdn.sofifa.net/players/188/545/23_60.png          Poland
# 56     https://cdn.sofifa.net/players/158/023/23_60.png       Argentina
# 75     https://cdn.sofifa.net/players/231/747/23_60.png          France
# 124    https://cdn.sofifa.net/players/165/153/23_60.png          France
# 3      https://cdn.sofifa.net/players/192/985/23_60.png         Belgium
# ...                                                 ...             ...
# ...

# %%
df_data.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value(£)', 'Wage(£)', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Joined', 'Loaned From', 'Contract Valid Until', 'Height(cm.)',
#        'Weight(lbs.)', 'Release Clause(£)', 'Kit Number',
#        'Best Overall Rating', 'Year_Joined'],
#       dtype='object')

# %%
df_data['Contract Valid Until'].hist(alpha=0.7)
# Out:
# <Axes: >

# %%
clubes = df_data['Club'].value_counts().index

clubes
# Out:
# Index(['Manchester United', 'Arsenal', 'FC Barcelona',
#        'Wolverhampton Wanderers', 'Atlético de Madrid', 'Chelsea',
#        'Paris Saint-Germain', 'Olympique de Marseille', 'Newcastle United',
#        'Real Madrid CF',
#        ...
#        'Once Caldas', 'Castellammare di Stabia', 'Southend United',
#        'SV Mattersburg', 'Livorno', 'FC Viitorul Constanța', 'Al Qadisiyah',
#        'VVV-Venlo', 'Club Independiente Santa Fe', 'Cusco Fútbol Club'],
#       dtype='object', name='Club', length=852)

# %%
player = 'Cristiano Ronaldo'

player_stats = df_data[df_data['Name'] == player].iloc[0]

player_stats['Photo']
# Out:
# 'https://cdn.sofifa.net/players/020/801/23_60.png'
